# %% [markdown]
# <a href="https://colab.research.google.com/github/prodramp/python-projects/blob/main/Walmart-SuperMarket/Store_master_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import uuid

# %%
df = pd.read_csv('walmart_2018_11_06.csv')

# %%
df
# Out:
#                               name  \
# 0               Conway Supercenter
# 1             Sikeston Supercenter
# 2            Tahlequah Supercenter
# 3        Mountain Home Supercenter
# 4            Claremore Supercenter
# ...                            ...
# 4649  Pearland Neighborhood Market
# 4650       Bentonville Gas Station
# 4651         Millcreek Pickup only
# 4652            Dallas Supercenter
# 4653            Murray Pickup only
#
#                                                     url  \
# 0     https://www.walmart.com/store/5/conway-ar/details
# 1     https://www.walmart.com/store/9/sikeston-mo/de...
# 2     https://www.walmart.com/store/10/tahlequah-ok/...
# 3     https://www.walmart.com/store/11/mountain-home...
# 4     https://www.walmart.com/store/12/claremore-ok/...
# ...                                                 ...
# 4649  https://www.walmart.com/store/7361/pearland-tx...
# 4650  https://www.walmart.com/store/7368/bentonville...
# ...

# %%
df = df[['name', 'latitude', 'longitude']]

# %%
df
# Out:
#                               name   latitude   longitude
# 0               Conway Supercenter  35.108660  -92.436905
# 1             Sikeston Supercenter  36.857394  -89.586051
# 2            Tahlequah Supercenter  35.888765  -94.979859
# 3        Mountain Home Supercenter  36.354957  -92.341026
# 4            Claremore Supercenter  36.293955  -95.627125
# ...                            ...        ...         ...
# 4649  Pearland Neighborhood Market  29.556350  -95.415783
# 4650       Bentonville Gas Station  36.357486  -94.214669
# 4651         Millcreek Pickup only  40.691031 -111.846529
# 4652            Dallas Supercenter  32.963412  -96.770294
# 4653            Murray Pickup only  40.649827 -111.849349
#
# [4654 rows x 3 columns]

# %%
df['store_id'] = df.apply(lambda _: uuid.uuid4(), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                               name   latitude   longitude  \
# 0               Conway Supercenter  35.108660  -92.436905
# 1             Sikeston Supercenter  36.857394  -89.586051
# 2            Tahlequah Supercenter  35.888765  -94.979859
# 3        Mountain Home Supercenter  36.354957  -92.341026
# 4            Claremore Supercenter  36.293955  -95.627125
# ...                            ...        ...         ...
# 4649  Pearland Neighborhood Market  29.556350  -95.415783
# 4650       Bentonville Gas Station  36.357486  -94.214669
# 4651         Millcreek Pickup only  40.691031 -111.846529
# 4652            Dallas Supercenter  32.963412  -96.770294
# 4653            Murray Pickup only  40.649827 -111.849349
#
#                                   store_id
# 0     5eb5e7fc-88b6-4326-9f6f-c2bfee082258
# 1     03419f7a-e60f-4b7b-9bea-edff19c1a24a
# 2     a7b1bc6a-17b6-4de1-ae2e-eecd653bf891
# 3     bf317faf-d154-4980-a8d1-83161bfbbacf
# 4     04508372-c00b-4e4c-a486-524e9730040f
# ...

# %%
df.to_csv('master_store_data.csv')

# %%
# !ls -lash /content
# Out:
# total 1.5M
# 4.0K drwxr-xr-x 1 root root 4.0K Apr 23 00:13 .
# 4.0K drwxr-xr-x 1 root root 4.0K Apr 23 00:02 ..
# 4.0K drwxr-xr-x 4 root root 4.0K Apr 19 14:22 .config
# 392K -rw-r--r-- 1 root root 389K Apr 23 00:13 master_store_data.csv
# 4.0K drwxr-xr-x 1 root root 4.0K Apr 19 14:23 sample_data
# 1.1M -rw-r--r-- 1 root root 1.1M Apr 23 00:04 walmart_2018_11_06.csv
